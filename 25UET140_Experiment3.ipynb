# %%
age=int(input("enter age:"))
if age>= 18:
    print("eligible for vote")
# Out:
# enter age:20
# eligible for vote

# %%
marks=int(input("enter marks:"))
if marks>=60:
    print("pass")
else:
    print("fail")
# Out:
# enter marks:50
# fail

# %%
a=int(input("enter first number:"))
b=int(input("enter second number:"))
c=int(input("enter third number:"))
if a>=b and a>=c:
    print("a is gretest number:",a)
elif b>=a and b>=c:
    print("b is gretest number:",b)
else:
    print("c is gretest number:",c)
# Out:
# enter first number:5
# enter second number:76
# enter third number:28
# b is gretest number: 76

# %%
num = int(input("Enter a number: "))

if num >= 0:
    if num % 2 == 0:
        print("The number is Even")
    else:
        print("The number is Odd")
# Out:
# Enter a number: 66
# The number is Even

# %%
n=int(input("enter number:"))
if n>=0:
    if n==0:
        print("zero")
    else:
        print("positive")
else:
    print("negative")
# Out:
# enter number:-14
# negative

# %%
age=int(input("enter age:"))
if age>=20:
    print("eligible for driving")
# Out:
# enter age:30
# eligible for driving
