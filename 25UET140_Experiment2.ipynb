# %%
text = "welcome to dkte"
print(text)
# Out:
# welcome to dkte

# %%
print("dkte "*5)
# Out:
# dkte dkte dkte dkte dkte

# %%
a= "welcome"
b= "to dkte"
print(a)
print(b)
print(a+" "+b)
# Out:
# welcome
# to dkte
# welcome to dkte

# %%
print("welcome" in text)
# Out:
# True

# %%
print("DKTE"in text)
# Out:
# False

# %%
print ("to" not in text)
# Out:
# False

# %%
print("welcome"not in text)
# Out:
# False

# %%
print(text[0])
# Out:
# w

# %%
print(text[3:6])
# Out:
# com

# %%
print(len(text))
# Out:
# 15

# %%
text="welcome to dkte"
print(text.lower())
print(text.upper())
# Out:
# welcome to dkte
# WELCOME TO DKTE

# %%
print(text.swapcase())
# Out:
# WELCOME TO DKTE

# %%
print(text.title())
print(text.split())
print(text.capitalize())
print(text.find("dkte"))
print(text.rstrip())
print(text.lstrip())
print(text.strip())
print(text.startswith("w"))
print(text.endswith("E"))
print(text.count("e"))
# Out:
# Welcome To Dkte
# ['welcome', 'to', 'dkte']
# Welcome to dkte
# 11
# welcome to dkte
# welcome to dkte
# welcome to dkte
# True
# False
# 3

# %%
t=text.replace("welcome","invite")
print(t)
# Out:
# invite to dkte

# %%
T=['sneha','sanjyoti','tejas','tanishka']
print("-".join(T))
# Out:
# sneha-sanjyoti-tejas-tanishka
