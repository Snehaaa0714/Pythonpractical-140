# %%
a=int(input ("enter age"))
print ("age after one year")
# Out:
# enter age18
# age after one year

# %%
a=int (input("enter a first number"))
b=int(input("enter a second number"))
print("sum=",a+b)
print("difference=",a-b)
print("multiplication=",a*b)
print("mode=",a%b)
print("division=",a/b)
print("exponent=",a**b)
print("equal to",a==b)
print("Not equal to",a!=b)
print("Greater than",a>b)
print("And",a>1 and b<5)
# Out:
# enter a first number2
# enter a second number3
# sum= 5
# difference= -1
# multiplication= 6
# mode= 2
# division= 0.6666666666666666
# exponent= 8
# equal to False
# Not equal to True
# Greater than False
# And True

# %%
s="sneha"
a=2.34
b=28
c=[10,20,30]
d=(7,14,28)
e=False
f=14j
print(type(s))
print(type(a))
print (type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'list'>
# <class 'tuple'>
# <class 'bool'>
# <class 'complex'>

# %%
print("a","b","c",sep=" ")
# Out:
# a b c

# %%
print("DKTE\n sneha")
# Out:
# DKTE
#  sneha

# %%
print("Sneha",end=" ")
print("DKTE")
# Out:
# Sneha DKTE

# %%
print("Sneha\tGauri\tsanjyoti")
# Out:
# Sneha	Gauri	sanjyoti

# %%
name="Sneha"
age="18"
print(f" my name is {name} and age is {age}")
print (f" sum of 14 and 28 is {14+28}")
# Out:
#  my name is Sneha and age is 18
#  sum of 14 and 28 is 42
